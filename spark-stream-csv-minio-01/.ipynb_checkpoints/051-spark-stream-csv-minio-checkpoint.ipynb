# %% [markdown]
# # Initialization

# %%
# %run 050-init.ipynb
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 3.4.1
#       /_/
#
# Using Scala version 2.12.17, OpenJDK 64-Bit Server VM, 17.0.8
# Branch HEAD
# Compiled by user centos on 2023-06-19T23:01:01Z
# Revision 6b1ff22dde1ead51cbf370be6e48a802daae58b6
# Url https://github.com/apache/spark
# Type --help for more information.
# --2023-08-30 13:42:04--  https://raw.githubusercontent.com/meddash-cloud/meddash-public-datasets/main/data/walmart_stock.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90266 (88K) [text/plain]
# Saving to: ‘walmart_stock.csv’
#
# walmart_stock.csv   100%[===================>]  88.15K  --.-KB/s    in 0.01s
#
# ...

# %% [markdown]
# # Streaming on built-in stream named 'rate'

# %%
import os
csv_sdf = spark\
.readStream\
.format("rate")\
.option("rowsPerSecond", 3)\
.load()\
.writeStream\
.format("memory")\
.outputMode("update")\
.queryName("mem_results")\
.start()

# %%
display(csv_sdf.status)
# Out:
# {'message': 'Processing new data',
#  'isDataAvailable': True,
#  'isTriggerActive': True}

# %%
csv_sdf.recentProgress
# Out:
# [{'id': 'e7ef59e6-98ee-4c8a-b9e1-7e7623010488',
#   'runId': '2f0e437d-c366-414b-8d77-2e9c0287f356',
#   'name': 'mem_results',
#   'timestamp': '2023-08-30T14:05:48.235Z',
#   'batchId': 0,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'addBatch': 203,
#    'commitOffsets': 145,
#    'getBatch': 2,
#    'latestOffset': 0,
#    'queryPlanning': 19,
#    'triggerExecution': 430,
#    'walCommit': 50},
#   'stateOperators': [],
#   'sources': [{'description': 'RateStreamV2[rowsPerSecond=3, rampUpTimeSeconds=0, numPartitions=default',
#     'startOffset': None,
#     'endOffset': 0,
#     'latestOffset': 0,
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0}],
#   'sink': {'description': 'MemorySink', 'numOutputRows': 0}},
#  {'id': 'e7ef59e6-98ee-4c8a-b9e1-7e7623010488',
#   'runId': '2f0e437d-c366-414b-8d77-2e9c0287f356',
#   'name': 'mem_results',
# ...

# %%
spark.sql("show tables").show()
# Out:
# +---------+-----------+-----------+
# |namespace|  tableName|isTemporary|
# +---------+-----------+-----------+
# |         |mem_results|       true|
# +---------+-----------+-----------+

# %%
spark.sql("select * from mem_results").show(n=3)
# Out:
# +--------------------+-----+
# |           timestamp|value|
# +--------------------+-----+
# |2023-08-30 14:05:...|    0|
# |2023-08-30 14:05:...|    1|
# |2023-08-30 14:05:...|    2|
# +--------------------+-----+
# only showing top 3 rows
